# %%
from huggingface_hub import snapshot_download

# 下载真正的 MAE 模型（timm 官方）
snapshot_download(
    repo_id="timm/vit_base_patch16_224.mae",
    local_dir="/root/autodl-tmp/new_mae_model",
    endpoint="https://hf-mirror.com"  # 国内加速
)
print("✅ MAE 模型下载完成！")
# Out:
# ...
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# ✅ MAE 模型下载完成！
